# %%
import pandas as pd

batter_df = pd.read_csv("../data/processed/batter_ft.csv")
print(batter_df.columns.tolist())

bowler_df = pd.read_csv("../data\processed/bowler_ft.csv")
print(bowler_df.columns.tolist())
# Out:
# ['match_id', 'date', 'venue', 'innings', 'team', 'opp', 'batter', 'runs', 'balls', 'fours', 'sixes', 'team_score', 'outs', 'SR', 'avg_runs', 'sr', 'avg_balls', 'avg_venue_runs', 'avg_opp_runs', 'avg_4s', 'avg_6s', 'boundary_pct', 'avg_out']
# ['match_id', 'date', 'venue', 'innings', 'opp', 'team', 'bowler', 'balls', 'runs', 'wkts', 'overs', 'econ', 'avg_wkts', 'avg_eco', 'avg_runs_given', 'avg_venue_wkts', 'avg_opp_wkts']
# <>:6: SyntaxWarning: invalid escape sequence '\p'
# <>:6: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\Alpha\AppData\Local\Temp\ipykernel_14192\2102317161.py:6: SyntaxWarning: invalid escape sequence '\p'
#   bowler_df = pd.read_csv("../data\processed/bowler_ft.csv")
