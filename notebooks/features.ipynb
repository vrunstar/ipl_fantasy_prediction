# %%
import pandas as pd

# %%
batters = pd.read_csv("../data/processed/batter_ft.csv")
bowlers = pd.read_csv("../data/processed/bowler_ft.csv")

# %%
batters.shape, bowlers.shape
# Out:
# ((17708, 23), (13878, 17))

# %%
batters.head(5)
# Out:
#    match_id        date                                      venue  innings  \
# 0    548346  2012-04-29                           Wankhede Stadium        1
# 1    548352  2012-05-04            MA Chidambaram Stadium, Chepauk        2
# 2    548359  2012-05-08  Rajiv Gandhi International Stadium, Uppal        2
# 3    548373  2012-05-18  Rajiv Gandhi International Stadium, Uppal        2
# 4    548376  2012-05-20  Rajiv Gandhi International Stadium, Uppal        1
#
#               team                          opp          batter  runs  balls  \
# 0  Deccan Chargers               Mumbai Indians  A Ashish Reddy    10     10
# 1  Deccan Chargers          Chennai Super Kings  A Ashish Reddy     3      3
# 2  Deccan Chargers              Kings XI Punjab  A Ashish Reddy     8      8
# 3  Deccan Chargers             Rajasthan Royals  A Ashish Reddy    10      4
# 4  Deccan Chargers  Royal Challengers Bangalore  A Ashish Reddy     4      5
#
# ...

# %%
bowlers.head()
# Out:
#    match_id        date                            venue  innings  \
# 0    548341  2012-04-26       Subrata Roy Sahara Stadium        2
# 1    548346  2012-04-29                 Wankhede Stadium        2
# 2    548348  2012-05-01                 Barabati Stadium        2
# 3    548352  2012-05-04  MA Chidambaram Stadium, Chepauk        1
# 4    548356  2012-05-06            M Chinnaswamy Stadium        2
#
#                opp                         team          bowler  balls  runs  \
# 0  Deccan Chargers                Pune Warriors  A Ashish Reddy     24    32
# 1  Deccan Chargers               Mumbai Indians  A Ashish Reddy     14    11
# 2  Deccan Chargers                Pune Warriors  A Ashish Reddy     19    32
# 3  Deccan Chargers          Chennai Super Kings  A Ashish Reddy     13    16
# 4  Deccan Chargers  Royal Challengers Bangalore  A Ashish Reddy     25    36
#
#    wkts  overs   econ  avg_wkts   avg_eco  avg_runs_given  avg_venue_wkts  \
# ...

# %%
batters[['batter', 'date', 'runs', 'avg_runs', 'sr', 'avg_balls', 'avg_venue_runs', 'avg_opp_runs', 'avg_4s', 'avg_6s','boundary_pct', 'avg_out']].head()
# Out:
#            batter        date  runs  avg_runs     sr  avg_balls  \
# 0  A Ashish Reddy  2012-04-29    10      0.00    0.0       0.00
# 1  A Ashish Reddy  2012-05-04     3     10.00  100.0      10.00
# 2  A Ashish Reddy  2012-05-08     8      6.50  100.0       6.50
# 3  A Ashish Reddy  2012-05-18    10      7.00  100.0       7.00
# 4  A Ashish Reddy  2012-05-20     4      7.75  137.5       6.25
#
#    avg_venue_runs  avg_opp_runs    avg_4s    avg_6s  boundary_pct  avg_out
# 0             0.0           0.0  0.000000  0.000000       0.00000     0.00
# 1             0.0           0.0  0.000000  1.000000       0.10000     1.00
# 2             0.0           0.0  0.000000  0.500000       0.05000     1.00
# 3             8.0           0.0  0.333333  0.333333       0.07500     1.00
# 4             9.0           0.0  0.750000  0.250000       0.18125     0.75

# %%
bowlers[['bowler', 'wkts', 'runs', 'avg_wkts', 'avg_runs_given', 'avg_eco', 'avg_venue_wkts', 'avg_opp_wkts']].sample(5)
# Out:
#               bowler  wkts  runs  avg_wkts  avg_runs_given  avg_eco  \
# 293          A Nehra     1    33       0.4            26.4    7.698
# 7581        MW Short     0     7       0.0             9.0    6.500
# 3912   Harpreet Brar     0    20       0.0            24.4    8.114
# 1424  Arshdeep Singh     0    39       1.6            44.0   10.324
# 9463   R Sai Kishore     4    33       1.0            27.0    7.944
#
#       avg_venue_wkts  avg_opp_wkts
# 293              0.0           0.0
# 7581             0.0           0.0
# 3912             0.0           0.0
# 1424             0.0           1.6
# 9463             0.0           1.0

# %%
batters.isnull().sum()
# Out:
# match_id          0
# date              0
# venue             0
# innings           0
# team              0
# opp               0
# batter            0
# runs              0
# balls             0
# fours             0
# sixes             0
# team_score        0
# outs              0
# SR                0
# avg_runs          0
# sr                0
# avg_balls         0
# avg_venue_runs    0
# avg_opp_runs      0
# avg_4s            0
# avg_6s            0
# boundary_pct      0
# avg_out           0
# dtype: int64

# %%
bowlers.isnull().sum()
# Out:
# match_id          0
# date              0
# venue             0
# innings           0
# opp               0
# team              0
# bowler            0
# balls             0
# runs              0
# wkts              0
# overs             0
# econ              0
# avg_wkts          0
# avg_eco           0
# avg_runs_given    0
# avg_venue_wkts    0
# avg_opp_wkts      0
# dtype: int64
